# %% [markdown]
# # İST266 - Hipotez Testleri Proje Ödevi

# %% [markdown]
# > NOT: Bu .ipynb dosyası üzerinden hazılarayacağım sonra word dosyasına aktaracağım. Sözel ifade ve anlatım için ..ipynb dosya yapısının da kullandığı markdown biçimini kullanacağım ve matematiksel ifade için de bu biçimin kullanmış olduğu LaTex sözdizimi ile ifade edeceğim.
#
# > Kodlama tarafında python kullanacağım, **numpy** ve **pandas** yeterli geleceğini düşünüyorum bu 2 kütüphane temelli gideceğim, görselleştirme ve sunum için de **matplotlib** kullanacağım.

# %% [markdown]
# ### Dikkat edilmesi gerekenler:
# > (Hadi'de ödev talimatlarında yer alan kısım.)
#
# * Araştırma yaparken yalnızca internetten kısa bilgiler toplamak yerine kitaplardan ve güvenilir akademik kaynaklardan yararlanmanız beklenmektedir. İnternet kaynakları kullanılabilir ancak tek başına yeterli kabul edilmeyecektir. Ödevde kullanılan her bilgi için kaynak gösterilmesi gerekmektedir.
# * Ödev kapsamında yazılan kodlar çalıştırılmış olmalı ve kodların çalıştırılması sonucunda elde edilen çıktılar alınarak rapora eklenmelidir. Kod bölümünde kodun kendisi, kodun kısa açıklaması, program çalıştırıldığında elde edilen çıktı ve çıktının yorumlanması yer almalıdır.
# * Hazırlanan ödev tek bir PDF dosyası olarak düzenlenmeli ve bu formatta sisteme yüklenmelidir.

# %% [markdown]
# Bu ödevde simülasyon yöntemleri kullanılarak ;
# * **Nokta Tahmini**
# * **Yansızlık**
# * **Tutarlılık**
# * **Etkinlik**
# * **Hata Kareler Ortalaması**
# kavramları uygulamalı olarak incelenecektir.

# %% [markdown]
# Kullanılıcak dağılım ;
#
# $X \sim N(\mu=50,\sigma^2=100)$
#
# Bu dağılım kullanarak $N=10.000$ büyüklüğünde bir kitle oluşturmamız isteniyor.

# %%
import numpy as np
import pandas as pd #Daha sonra kullanım için
import matplotlib as mpl # Daha sonra kullanma için
import os

rng = np.random.default_rng(seed=26)
kitle = rng.normal(loc=50, scale=10, size=10000)
print(kitle)
# Out:
# [30.74935502 19.81204769 61.54463147 ... 60.36609293 49.42113287
#  41.62076388]

# %%
rng = np.random.default_rng(26)
kitle2 = rng.normal(loc=50, scale=10, size=10000)
print(kitle2)
# Out:
# [30.74935502 19.81204769 61.54463147 ... 60.36609293 49.42113287
#  41.62076388]

# %% [markdown]
# > NOT : Her seferinde yeniden oluşturuyordu bu yüzden bir dosyaya kaydedip oradan çekmeye çalıştım ancak bu sefer de her seferinde yeniden aynı dosyayı oluşturuyor ve içerisinde yeni değerleri kaydediyordu bu yüzden os kütüphanesini kullanarak dosya var ise yeniden oluşturmamasını sadece o kitle değerlerimizi içeren dosyamızı çağırmamızı sağladım.

# %% [markdown]
# ### ÖDEV 1
#
# ### Bölüm 1 - Kitle Parametrelerinin Hesaplanması
#
# Oluşturduğumuz veri kümesini kitle olarak kabul edelim ve **kitle ortalaması**, **kitle varyansı** istatistiklerini hesaplayalım :

# %%
toplam = 0
for i in kitle:
    toplam += i
kitle_ort = toplam/len(kitle)
print(f"Kitle Ortalaması = {kitle_ort}")
# Out:
# Kitle Ortalaması = 50.106516550162944

# %% [markdown]
# Kitle varyansı = $\sigma^2 = \frac {\sum(Xi-\mu)^2}{N}$
# (bknz. İst. Yönt. Giriş 61.sf)

# %%
toplam = 0
for i in kitle:
    denklem = (i - kitle_ort)**2
    toplam += denklem
var_kitle = toplam/len(kitle)
print(f"Kitle Varyansı = {var_kitle}")
# Out:
# Kitle Varyansı = 99.12312792831436

# %% [markdown]
# ### Bölüm 2 - Farklı Örneklem Büyüklükleri ile Nokta Tahmini

# %% [markdown]
# Oluşturduğumuz kitleden;
#  - n=10 , n=30, n=100, n=500
# büyüklüklerinde örneklemler çkmemiz isteniyor.

# %% [markdown]
# > NOT : Aslında bu örneklemleri de ayrı dosyalar halinde tutacaktım ancak bölüm 3 de tutarlılık testi için 1000 adet örneklem ortalaması tekrarlattırıyor 1000 ayrı dosya şeklinde yapamam bu yüzden örneklem çekme aşamasında kitle kadar sabit olmadığından seed ile kitlemden örneklem çektiricem. Kitle için seed seçmeme sebebim yeterince random olduğunu düşünmememdi ancak mecbur örneklemler için seed mantığı ile gideceğim.

# %%
sample1 = rng.choice(kitle, size=10)
sample2 = rng.choice(kitle, size=30)
sample3 = rng.choice(kitle, size=100)
sample4 = rng.choice(kitle, size=500)

# %% [markdown]
#  > Aynı seed ile çekiyor randomizasyon artık belirli (seed 26 seçtim çünkü eskişehirliyim xD) ve sample lar birbirinden farklı. Ayrıca paramtre içinde de replacement=True bırakarak bağımsız örneklemler çektim.

# %% [markdown]
# X'in dağılımının parametrelerine ait nokta tahmini için neler kullanırsınız? **Elde ettiğiniz tahminleri kitle paramtreleri ile karşılaştırınız.**
#
# X'in dağılımı normal dağılım bu yüzden parametre tahminleri için :
# * ortalama parametresi için $\overline{x}$ (x ortalamayı)
# * Varyans parametresi içinde $S^2$ (örneklem ortalması),
# kullanırdım.
#
# Bu tahmin değerlerini hesaplayıp kitle parametreleri ile karşılaştıralım.
#
# $\overline{x} = \frac{\sum xi}{n}$

# %%
""" 
Her seferinde yeniden ort ve varyans için for yazmaktansa 
fonksiyon yazacağım
"""

def x_ort(sample, n):
    toplam = 0
    for i in sample:
        toplam += i 
    return (toplam/n)

def s_varyans(sample ,ort ,n):
    toplam = 0
    for i in sample:
        toplam += (i-ort)**2
    return (toplam)/(n-1)

# %%
ort_sample1 = x_ort(sample1,10)
print(f"1.örneklem için X ortalama = {ort_sample1}")
ort_sample2 = x_ort(sample2,30)
print(f"2.örneklem için X ortalama = {ort_sample2}")
ort_sample3 = x_ort(sample3,100)
print(f"3.örneklem için X ortalama = {ort_sample3}")
ort_sample4 = x_ort(sample4,500)
print(f"4.örneklem için X ortalama = {ort_sample4}")
# Out:
# 1.örneklem için X ortalama = 52.791015239757186
# 2.örneklem için X ortalama = 50.955202743029005
# 3.örneklem için X ortalama = 49.20121858929824
# 4.örneklem için X ortalama = 50.46481991140035

# %% [markdown]
# $S^2 = \frac{\sum (xi - \overline{X})^2}{n-1}$

# %%
var_sample1 = s_varyans(sample1,ort_sample1,10)
print(f"1.örneklem için örneklem varyansı = {var_sample1}")
var_sample2 = s_varyans(sample2,ort_sample2,30)
print(f"2.örneklem için örneklem varyansı = {var_sample2}")
var_sample3 = s_varyans(sample2,ort_sample2,100)
print(f"3.örneklem için örneklem varyansı = {var_sample3}")
var_sample4 = s_varyans(sample2,ort_sample2,500)
print(f"4.örneklem için örneklem varyansı = {var_sample4}")
# Out:
# 1.örneklem için örneklem varyansı = 193.03802949967704
# 2.örneklem için örneklem varyansı = 133.95230461982277
# 3.örneklem için örneklem varyansı = 39.23855387853394
# 4.örneklem için örneklem varyansı = 7.784803274498718

# %% [markdown]
# Çıkan sonuçlarımız =
